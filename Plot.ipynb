# %%
using Plots
using LaTeXStrings
# Out:
# ArgumentError: Package LaTeXStrings not found in current path.
# - Run `import Pkg; Pkg.add("LaTeXStrings")` to install the LaTeXStrings package.
#
# Stacktrace:
#  [1] macro expansion
#    @ ./loading.jl:1163 [inlined]
#  [2] macro expansion
#    @ ./lock.jl:223 [inlined]
#  [3] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1144

# %%
plot([0,1,2,3],xlabel="Some Numbers",grid = false)

# %%
t = 0:0.2:5
theme(:wong)
plot(t, t, color=:blue, xlab="t variable", label="linear")
plot!(t, t.^2, color =:red, label="square")
plot!(t, t.^3, color=:green, label="cubic")

# %% [markdown]
# ## Subplots and Layouts

# %%
l = @layout[
        [
            a{0.33h}
            b{0.33h}
            c{0.33h}
        ] [
        d{0.33h}
        e{0.33h}
        f{0.33h}
    ]
    ]

p1 = scatter()

p2 = histogram()

p3 = histogram()
p4 = histogram()

p5 = histogram()
p6 = histogram()

plot(p1,p2,p3,p4,p5,p6,layout = l)

# %% [markdown]
# ## Contour Plots

# %%
contourf(X[1,:], Y[:,1],Z, linewidth=0, grid=false)
# Out:
# UndefVarError: X not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[33]:1

# %% [markdown]
# ## Surface Plots

# %%
plotlyjs()
plot(X, Y, Z, st=:surface)

# %%
plot(rand(10), legend_position = :outertopleft)

# %%
a = 2
t  = "The number of apples is $a" #Latexstring needs %$a
println(t)
# Out:
# The number of apples is %2
